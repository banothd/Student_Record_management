# %%
# Student Record Management System Using Python

## Module 1 Project

**Name:** Your Name

**Course:** Python Programming

**Tools Used:** Python, Jupyter Notebook, SQLite, Streamlit

**Date:** DD/MM/YYYY

# %% [markdown]
# ## Business Problem Statement
#
# Educational institutions often manage student records manually using registers or spreadsheets, which can lead to data duplication, errors, and difficulty in retrieving information.
#
# As the number of students increases, maintaining accurate records becomes time-consuming and inefficient.

# %% [markdown]
# ## Proposed Solution
#
# The Student Record Management System digitizes student information management.
#
# The system enables users to add, update, search, and delete student records while storing data securely in a database.
#
# This solution reduces manual effort, improves accuracy, and simplifies record management.

# %% [markdown]
# ## Objectives
#
# - Store student records digitally
# - Add new student details
# - Search student information
# - Update student records
# - Delete student records
# - Calculate grades automatically
# - Generate summary statistics

# %%
import sqlite3
import os

# %%
import pandas as pd

# %%
class Student:

    def __init__(self, student_id, name, age, course, marks):

        self.student_id = student_id
        self.name = name
        self.age = age
        self.course = course
        self.marks = marks
        self.grade = self.calculate_grade()

    def calculate_grade(self):

        if self.marks >= 90:
            return "A+"
        elif self.marks >= 80:
            return "A"
        elif self.marks >= 70:
            return "B"
        elif self.marks >= 60:
            return "C"
        return "F"

# %%
DB_NAME = "students.db"

def connect_db():

    conn = sqlite3.connect(DB_NAME)

    conn.execute("""
        CREATE TABLE IF NOT EXISTS students (

            student_id INTEGER PRIMARY KEY,
            name TEXT NOT NULL,
            age INTEGER,
            course TEXT,
            marks REAL,
            grade TEXT
        )
    """)

    return conn

# %% [markdown]
# ## CRUD Operations

# %%
# View Students
def add_student(student):
    pass

# %%
# Search Students
def get_students():
    pass

# %%
# Update Student
def update_student(student):
    pass

# %% [markdown]
# ## Exception Handling
#
# The system validates:
#
# - Duplicate student IDs
# - Empty names
# - Invalid age values
# - Marks outside the range 0–100

# %% [markdown]
# ## Testing the Application

# %%
student1 = Student(
    101,
    "John",
    20,
    "Python",
    85
)

add_student(student1)

# %%
get_students()

# %%
search_student(101)

# %%
updated_student = Student(
    101,
    "John",
    21,
    "Data Science",
    92
)

update_student(updated_student)

# %%
delete_student(101)

# %% [markdown]
# ## Results
#
# The system successfully performs CRUD operations and stores student records using SQLite.
#
# The application automates grade calculation and improves efficiency in student data management.

# %% [markdown]
# ## Future Enhancements
#
# - Deploy using Streamlit
# - Add user authentication
# - Integrate cloud databases
# - Generate PDF reports
# - Add dashboards and analytics

# %% [markdown]
# ## Conclusion
#
# The Student Record Management System demonstrates the use of Python fundamentals, object-oriented programming, database connectivity, exception handling, and file management techniques.
#
# The project provides an efficient solution for managing student records digitally.
